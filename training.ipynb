# %% [markdown]
# # Training time

# %%
# import variables from other script?
# K said write preproc as a fn so it can return here. hmmm.
# if I pull that off, that means that a future user would be able to just download this notebook and go to town

from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, balanced_accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
# Out:
# 2024-03-24 18:04:27.417504: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-24 18:04:27.937978: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from preprocessing import run_preproc
X_train, X_test, y_train, y_test = run_preproc()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Timestamp                     736 non-null    object
#  1   Age                           735 non-null    float64
#  2   Primary streaming service     735 non-null    object
#  3   Hours per day                 736 non-null    float64
#  4   While working                 733 non-null    object
#  5   Instrumentalist               732 non-null    object
#  6   Composer                      735 non-null    object
#  7   Fav genre                     736 non-null    object
#  8   Exploratory                   736 non-null    object
#  9   Foreign languages             732 non-null    object
#  10  BPM                           629 non-null    float64
#  11  Frequency [Classical]         736 non-null    object
#  12  Frequency [Country]           736 non-null    object
#  13  Frequency [EDM]               736 non-null    object
#  14  Frequency [Folk]              736 non-null    object
#  15  Frequency [Gospel]            736 non-null    object
#  16  Frequency [Hip hop]           736 non-null    object
#  17  Frequency [Jazz]              736 non-null    object
#  18  Frequency [K pop]             736 non-null    object
#  19  Frequency [Latin]             736 non-null    object
#  20  Frequency [Lofi]              736 non-null    object
#  21  Frequency [Metal]             736 non-null    object
#  22  Frequency [Pop]               736 non-null    object
#  23  Frequency [R&B]               736 non-null    object
#  24  Frequency [Rap]               736 non-null    object
#  25  Frequency [Rock]              736 non-null    object
#  26  Frequency [Video game music]  736 non-null    object
#  27  Anxiety                       736 non-null    float64
#  28  Depression                    736 non-null    float64
#  29  Insomnia                      736 non-null    float64
#  30  OCD                           736 non-null    float64
#  31  Music effects                 728 non-null    object
#  32  Permissions                   736 non-null    object
# dtypes: float64(7), object(26)
# memory usage: 189.9+ KB
# Index(['timestamp', 'age', 'primary_streaming_service', 'hours_per_day',
#        'while_working', 'instrumentalist', 'composer', 'fav_genre',
#        'exploratory', 'foreign_languages', 'bpm', 'frequency_classical',
#        'frequency_country', 'frequency_edm', 'frequency_folk',
#        'frequency_gospel', 'frequency_hip_hop', 'frequency_jazz',
#        'frequency_k_pop', 'frequency_latin', 'frequency_lofi',
#        'frequency_metal', 'frequency_pop', 'frequency_r&b', 'frequency_rap',
#        'frequency_rock', 'frequency_video_game_music', 'anxiety', 'depression',
#        'insomnia', 'ocd', 'music_effects', 'permissions'],
#       dtype='object')
# 18 rows dropped (718 remaining)
# <class 'pandas.core.frame.DataFrame'>
# Index: 718 entries, 2 to 735
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   uuid                        718 non-null    object
#  1   age                         718 non-null    float64
#  2   primary_streaming_service   718 non-null    object
#  3   hours_per_day               718 non-null    float64
#  4   while_working               718 non-null    object
#  5   instrumentalist             718 non-null    object
#  6   composer                    718 non-null    object
#  7   fav_genre                   718 non-null    object
#  8   exploratory                 718 non-null    object
#  9   foreign_languages           718 non-null    object
#  10  frequency_classical         718 non-null    object
#  11  frequency_country           718 non-null    object
#  12  frequency_edm               718 non-null    object
#  13  frequency_folk              718 non-null    object
#  14  frequency_gospel            718 non-null    object
#  15  frequency_hip_hop           718 non-null    object
#  16  frequency_jazz              718 non-null    object
#  17  frequency_k_pop             718 non-null    object
#  18  frequency_latin             718 non-null    object
#  19  frequency_lofi              718 non-null    object
#  20  frequency_metal             718 non-null    object
#  21  frequency_pop               718 non-null    object
#  22  frequency_r&b               718 non-null    object
#  23  frequency_rap               718 non-null    object
#  24  frequency_rock              718 non-null    object
#  25  frequency_video_game_music  718 non-null    object
#  26  anxiety                     718 non-null    float64
#  27  depression                  718 non-null    float64
#  28  insomnia                    718 non-null    float64
#  29  ocd                         718 non-null    float64
#  30  music_effects               718 non-null    float64
# dtypes: float64(7), object(24)
# memory usage: 179.5+ KB
# running preprocessing...
# Index(['age', 'hours_per_day', 'while_working', 'instrumentalist', 'composer',
#        'exploratory', 'foreign_languages', 'frequency_classical',
#        'frequency_country', 'frequency_edm', 'frequency_folk',
#        'frequency_gospel', 'frequency_hip_hop', 'frequency_jazz',
#        'frequency_k_pop', 'frequency_latin', 'frequency_lofi',
#        'frequency_metal', 'frequency_pop', 'frequency_r&b', 'frequency_rap',
#        'frequency_rock', 'frequency_video_game_music', 'anxiety', 'depression',
#        'insomnia', 'ocd', 'music_effects',
#        'primary_streaming_service_apple_music',
#        'primary_streaming_service_i_do_not_use_a_streaming_service.',
#        'primary_streaming_service_other_streaming_service',
#        'primary_streaming_service_pandora',
#        'primary_streaming_service_spotify',
#        'primary_streaming_service_youtube_music', 'fav_genre_classical',
#        'fav_genre_country', 'fav_genre_edm', 'fav_genre_folk',
#        'fav_genre_gospel', 'fav_genre_hip_hop', 'fav_genre_jazz',
#        'fav_genre_k_pop', 'fav_genre_latin', 'fav_genre_lofi',
#        'fav_genre_metal', 'fav_genre_pop', 'fav_genre_r&b', 'fav_genre_rap',
#        'fav_genre_rock', 'fav_genre_video_game_music'],
#       dtype='object')
# Training features shape: (574, 49)
# Training targets shape: (574,)
# Testing features shape: (144, 49)
# Testing targets shape: (144,)
# 574
# music_effects
# 1.0    535
# 0.0    183
# Name: count, dtype: int64
# [(0.0, 423), (1.0, 423)]
# running preprocessing...
# Index(['age', 'hours_per_day', 'while_working', 'instrumentalist', 'composer',
#        'exploratory', 'foreign_languages', 'frequency_classical',
#        'frequency_country', 'frequency_edm', 'frequency_folk',
#        'frequency_gospel', 'frequency_hip_hop', 'frequency_jazz',
#        'frequency_k_pop', 'frequency_latin', 'frequency_lofi',
#        'frequency_metal', 'frequency_pop', 'frequency_r&b', 'frequency_rap',
#        'frequency_rock', 'frequency_video_game_music', 'anxiety', 'depression',
#        'insomnia', 'ocd', 'music_effects',
#        'primary_streaming_service_apple_music',
#        'primary_streaming_service_i_do_not_use_a_streaming_service.',
#        'primary_streaming_service_other_streaming_service',
#        'primary_streaming_service_pandora',
#        'primary_streaming_service_spotify',
#        'primary_streaming_service_youtube_music', 'fav_genre_classical',
#        'fav_genre_country', 'fav_genre_edm', 'fav_genre_folk',
#        'fav_genre_gospel', 'fav_genre_hip_hop', 'fav_genre_jazz',
#        'fav_genre_k_pop', 'fav_genre_latin', 'fav_genre_lofi',
#        'fav_genre_metal', 'fav_genre_pop', 'fav_genre_r&b', 'fav_genre_rap',
#        'fav_genre_rock', 'fav_genre_video_game_music'],
#       dtype='object')
# Training features shape: (574, 49)
# Training targets shape: (574,)
# Testing features shape: (144, 49)
# Testing targets shape: (144,)
# 574
# music_effects
# 1.0    535
# 0.0    183
# Name: count, dtype: int64
# [(0.0, 423), (1.0, 423)]
# /home/giacomo/proj/final/cleaning.py:63: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace({

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### I. Logistic Regression

# %%
print(len(X_train))
# Out:
# 846

# %%
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_clf_pred = clf.predict(X_test)

print(accuracy_score(y_train, clf.predict(X_train)))
balanced_accuracy_score(y_train, clf.predict(X_train))
# Out:
# 0.6903073286052009
# 0.6903073286052009

# %%
print(accuracy_score(y_test, y_clf_pred))
balanced_accuracy_score(y_test, y_clf_pred)
# Out:
# 0.6111111111111112
# 0.5825892857142857

# %% [markdown]
# ### II. Random Forest

# %%
# Initialize the Random Forest Classifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model
# Out:
# RandomForestClassifier(random_state=42)

# %%
print(f'X_train len: {len(X_train)}')
print(f'y_train len: {len(y_train)}')
# Out:
# X_train len: 846
# y_train len: 846

# %%
rf_model.fit(X_train, y_train)
y_pred = rf_model.predict(X_test)

# %%
# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.7291666666666666

# %%
# Calculate accuracy
bal_accuracy = balanced_accuracy_score(y_test, y_pred)
print(f"Balanced accuracy: {bal_accuracy}")
# Out:
# Balanced accuracy: 0.5245535714285714

# %%
# Generate a classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.29      0.16      0.20        32
#          1.0       0.79      0.89      0.84       112
#
#     accuracy                           0.73       144
#    macro avg       0.54      0.52      0.52       144
# weighted avg       0.68      0.73      0.70       144

# %%
# Generate and display a confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print(conf_matrix)
# Out:
# [[  5  27]
#  [ 12 100]]

# %% [markdown]
# ### III. Tensorflow

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test = X_scaler.transform(X_test)
print(len(X_train[0]))
X_train[0]
# Out:
# 49
# array([-0.51622839,  0.45562066,  0.51411787,  1.46759877, -0.47591567,
#         0.62705971, -1.08362467,  0.64714199,  0.21466409, -0.9944341 ,
#        -1.01495729, -0.54103769, -0.36041035,  0.99341549, -0.72061693,
#        -0.72773606, -1.02678292,  1.56139377, -0.04567561,  0.68371222,
#        -0.30937077,  0.88291091, -1.15672096, -1.40313776, -0.92373616,
#        -1.22465478,  1.21273137, -0.29516303, -0.33204134, -0.28097574,
#        -0.11111111,  0.79415478, -0.372678  , -0.28456859, -0.19000285,
#        -0.23893564, -0.19000285, -0.10277831, -0.22217143, -0.1693335 ,
#        -0.16380974, -0.0417756 , -0.11888766, -0.3665888 , -0.43121968,
#        -0.21781932, -0.1693335 ,  1.67371578, -0.25867837])

# %%
# Define the model - deep neural net
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  100
hidden_nodes_layer2 = 20

nn = tf.keras.models.Sequential()

# %%
# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 100)            │         5,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 20)             │         2,020 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            21 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 100)            │           200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 20)             │         2,020 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,282 (36.26 KB)
#  Trainable params: 9,282 (36.26 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 789us/step - accuracy: 0.5129 - loss: 0.6923
# Epoch 2/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step - accuracy: 0.5406 - loss: 0.6831
# Epoch 3/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step - accuracy: 0.6800 - loss: 0.6572
# Epoch 4/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step - accuracy: 0.7559 - loss: 0.6080
# Epoch 5/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - accuracy: 0.8222 - loss: 0.5472
# Epoch 6/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step - accuracy: 0.8321 - loss: 0.4881
# Epoch 7/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step - accuracy: 0.8939 - loss: 0.3820
# Epoch 8/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - accuracy: 0.9244 - loss: 0.3006
# Epoch 9/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step - accuracy: 0.9441 - loss: 0.2321
# Epoch 10/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - accuracy: 0.9582 - loss: 0.1928
# Epoch 11/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - accuracy: 0.9756 - loss: 0.1229
# Epoch 12/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step - accuracy: 0.9755 - loss: 0.1262
# Epoch 13/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - accuracy: 0.9802 - loss: 0.0922
# Epoch 14/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - accuracy: 0.9907 - loss: 0.0608
# Epoch 15/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - accuracy: 0.9857 - loss: 0.0728
# Epoch 16/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step - accuracy: 0.9895 - loss: 0.0557
# Epoch 17/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step - accuracy: 0.9904 - loss: 0.0511
# Epoch 18/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step - accuracy: 0.9917 - loss: 0.0449
# Epoch 19/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step - accuracy: 0.9910 - loss: 0.0473
# Epoch 20/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - accuracy: 0.9879 - loss: 0.0579
# Epoch 21/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - accuracy: 0.9869 - loss: 0.0608
# Epoch 22/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - accuracy: 0.9870 - loss: 0.0601
# Epoch 23/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - accuracy: 0.9888 - loss: 0.0534
# Epoch 24/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step - accuracy: 0.9942 - loss: 0.0330
# Epoch 25/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step - accuracy: 0.9915 - loss: 0.0427
# Epoch 26/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - accuracy: 0.9929 - loss: 0.0376
# Epoch 27/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step - accuracy: 0.9910 - loss: 0.0445
# Epoch 28/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - accuracy: 0.9828 - loss: 0.0733
# Epoch 29/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - accuracy: 0.9852 - loss: 0.0639
# Epoch 30/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - accuracy: 0.9856 - loss: 0.0626
# Epoch 31/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - accuracy: 0.9842 - loss: 0.0673
# Epoch 32/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - accuracy: 0.9916 - loss: 0.0400
# Epoch 33/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step - accuracy: 0.9862 - loss: 0.0592
# Epoch 34/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - accuracy: 0.9910 - loss: 0.0426
# Epoch 35/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step - accuracy: 0.9846 - loss: 0.0633
# Epoch 36/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - accuracy: 0.9904 - loss: 0.0435
# Epoch 37/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - accuracy: 0.9880 - loss: 0.0510
# Epoch 38/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step - accuracy: 0.9889 - loss: 0.0466
# Epoch 39/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - accuracy: 0.9909 - loss: 0.0401
# Epoch 40/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step - accuracy: 0.9877 - loss: 0.0498
# Epoch 41/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step - accuracy: 0.9903 - loss: 0.0397
# Epoch 42/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - accuracy: 0.9892 - loss: 0.0428
# Epoch 43/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - accuracy: 0.9857 - loss: 0.0531
# Epoch 44/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step - accuracy: 0.9877 - loss: 0.0457
# Epoch 45/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - accuracy: 0.9814 - loss: 0.0625
# Epoch 46/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - accuracy: 0.9912 - loss: 0.0335
# Epoch 47/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - accuracy: 0.9878 - loss: 0.0415
# Epoch 48/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - accuracy: 0.9898 - loss: 0.0361
# Epoch 49/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - accuracy: 0.9904 - loss: 0.0325
# Epoch 50/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - accuracy: 0.9860 - loss: 0.0416
# Epoch 51/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - accuracy: 0.9950 - loss: 0.0194
# Epoch 52/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - accuracy: 0.9872 - loss: 0.0363
# Epoch 53/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step - accuracy: 0.9883 - loss: 0.0333
# Epoch 54/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step - accuracy: 0.9904 - loss: 0.0269
# Epoch 55/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - accuracy: 0.9917 - loss: 0.0233
# Epoch 56/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - accuracy: 0.9922 - loss: 0.0200
# Epoch 57/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - accuracy: 0.9838 - loss: 0.0351
# Epoch 58/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - accuracy: 0.9901 - loss: 0.0233
# Epoch 59/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 473us/step - accuracy: 0.9886 - loss: 0.0288
# Epoch 60/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step - accuracy: 0.9581 - loss: 0.1053
# Epoch 61/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step - accuracy: 0.9504 - loss: 0.1392
# Epoch 62/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step - accuracy: 0.9654 - loss: 0.0966
# Epoch 63/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step - accuracy: 0.9763 - loss: 0.0588
# Epoch 64/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - accuracy: 0.9919 - loss: 0.0281
# Epoch 65/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - accuracy: 0.9853 - loss: 0.0359
# Epoch 66/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - accuracy: 0.9852 - loss: 0.0319
# Epoch 67/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - accuracy: 0.9839 - loss: 0.0326
# Epoch 68/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - accuracy: 0.9918 - loss: 0.0181
# Epoch 69/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - accuracy: 0.9862 - loss: 0.0261
# Epoch 70/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step - accuracy: 0.9861 - loss: 0.0230
# Epoch 71/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - accuracy: 0.9913 - loss: 0.0161
# Epoch 72/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - accuracy: 0.9906 - loss: 0.0159
# Epoch 73/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step - accuracy: 0.9846 - loss: 0.0214
# Epoch 74/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - accuracy: 0.9844 - loss: 0.0201
# Epoch 75/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - accuracy: 0.9848 - loss: 0.0188
# Epoch 76/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step - accuracy: 0.9883 - loss: 0.0142
# Epoch 77/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 459us/step - accuracy: 0.9872 - loss: 0.0144
# Epoch 78/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step - accuracy: 0.9845 - loss: 0.0158
# Epoch 79/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - accuracy: 0.9903 - loss: 0.0100
# Epoch 80/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 452us/step - accuracy: 0.9820 - loss: 0.0158
# Epoch 81/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - accuracy: 0.9941 - loss: 0.0106
# Epoch 82/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - accuracy: 0.9967 - loss: 0.0131
# Epoch 83/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 462us/step - accuracy: 0.9997 - loss: 0.0098
# Epoch 84/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - accuracy: 1.0000 - loss: 0.0119
# Epoch 85/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step - accuracy: 1.0000 - loss: 0.0074
# Epoch 86/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 459us/step - accuracy: 1.0000 - loss: 0.0107
# Epoch 87/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - accuracy: 1.0000 - loss: 0.0096
# Epoch 88/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - accuracy: 1.0000 - loss: 0.0070
# Epoch 89/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - accuracy: 1.0000 - loss: 0.0057
# Epoch 90/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step - accuracy: 1.0000 - loss: 0.0068
# Epoch 91/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - accuracy: 1.0000 - loss: 0.0052
# Epoch 92/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - accuracy: 1.0000 - loss: 0.0063
# Epoch 93/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - accuracy: 1.0000 - loss: 0.0051
# Epoch 94/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - accuracy: 1.0000 - loss: 0.0075
# Epoch 95/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - accuracy: 1.0000 - loss: 0.0046
# Epoch 96/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step - accuracy: 1.0000 - loss: 0.0047
# Epoch 97/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 473us/step - accuracy: 1.0000 - loss: 0.0036
# Epoch 98/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step - accuracy: 1.0000 - loss: 0.0041
# Epoch 99/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 100/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step - accuracy: 1.0000 - loss: 0.0024

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 5/5 - 0s - 13ms/step - accuracy: 0.7083 - loss: 1.7125
# Loss: 1.712533950805664, Accuracy: 0.7083333134651184
